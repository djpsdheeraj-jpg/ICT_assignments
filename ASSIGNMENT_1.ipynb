# %% [markdown]
# <a href="https://colab.research.google.com/github/djpsdheeraj-jpg/ICT_assignments/blob/main/ASSIGNMENT_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
item=int(input('enter the item 1 price'))
q1=int(input('enter the quandity of item 1:'))
item2=int(input('enter the item 2 price'))
q2=int(input('enter the item 2 quandity:'))
total_bill=item*q1+item2*q2
print('total bill:',total_bill)
# Out:
# enter the item 1 price45
# enter the quandity of item 1:3
# enter the item 2 price30
# enter the item 2 quandity:2
# total bill: 195

# %%
t=int(input('enter temperature in celsius:'))
f=(t*9/5)+32
print('temperature in fahrenhelt:',f)
# Out:
# enter temperature in celsius:30
# temperature in fahrenhelt: 86.0

# %%
s=int(input('enter the basic salary:',))
hra=(0.2*s)
da=(0.1*s)
net_salarys=s+hra+da
print('net salary:',net_salarys)
# Out:
# enter the basic salary:20000
# net salary: 26000.0

# %%
p=int(input('enter the principal amount:'))
r=int(input('enter the rate of interest:'))
t=int(input('enter the time in year:'))
s1=p*r*t/100
print('simple interest:',s1)
# Out:
# enter the principal amount:10000
# enter the rate of interest:5
# enter the time in year:2
# simple interest 1000.0

# %%
time=int(input('enter the total minutes:'))
hour=time//60
minute=time%60
print('hour:',hour)
print('minute:',minute)
# Out:
# enter the total minutes:130
# hour: 2
# minute: 10

# %%
w=int(input('enter the weight in kg:'))
h=float(input('enter the height in cm:'))
h1=h/200
bmi=w/(h*h)
print('bmi:',bmi)
# Out:
# enter the weight in kg:60
# enter the height in cm:1.65
# bmi: 22.03856749311295

# %%
p=int(input('enter the original amount'))
d=int(input('enter the discount percentage:'))
discount=(d/100)
print('new price:',discount)
# Out:
# enter the original amount1200
# enter the discount percentage:10
# new price: 0.1

# %%
a=int(input('enter side a:'))
b=int(input('enter side b:'))
c=int(input('enter side c:'))
s=(a+b+c)/2
area=(s*(s-a)*(s-b)*(s-c)**0.5
print(area)
# Out:
#   File "/tmp/ipython-input-3093018631.py", line 5
#     area=(s*(s-a)*(s-b)*(s-c)**0.5
#          ^
# SyntaxError: '(' was never closed

# %%
1=int(input('enter the length:'))
